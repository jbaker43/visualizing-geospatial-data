# %%
#https://www.kaggle.com/datasets/tipsijadav/covid19-ct

# %%
import nibabel as nib #packages we need
import matplotlib.pyplot as plt
from nilearn import plotting

# %%
img = nib.load('data/BrainTumorProgression/03/Post_Scan_T1.nii') #setting img to one of our .nii files

# %%
data = img.get_data() #setting data to the value returned by get_data
# Out:
# <ipython-input-3-c24375ef6979>:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   data = img.get_data() #setting data to the value returned by get_data

# %%
type(img) #we can look at the type
# Out:
# nibabel.nifti1.Nifti1Image

# %%
print(img.header) #the information in the header of the .nii file
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 256 256  24   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float64
# bitpix          : 64
# slice_start     : 0
# pixdim          : [1. 1. 1. 1. 0. 0. 0. 0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : unknown
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : -0.0
# ...

# %%
img.shape #we can look at the shap of one of the .nii files
# Out:
# (256, 256, 24)

# %%
plotting.plot_img('data/BrainTumorProgression/03/Pre_Mask.nii')   #pre
plotting.plot_img('data/BrainTumorProgression/03/Post_Mask.nii')  #post
plotting.plot_img('data/BrainTumorProgression/03/Pre_Scan_T1.nii')  #pre
plotting.plot_img('data/BrainTumorProgression/03/Post_Scan_T1.nii')  #post
